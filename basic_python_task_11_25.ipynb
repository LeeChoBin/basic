# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/basic_python_task_11_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#파이썬에서 조건식과 수학 연산자에 대해 써서 올리기 행정학과 2100465 이초빈
# 먼저, 파이썬의 수학  연산자들에 대해 알아볼 것이다. 파이썬의 연산자는 덧셈, 뺄셈, 곱셈, 정수 나눗셈, 실수 나눗셈,나머지 연산자, 지수 연산자 등이 있다.
# 이러한 연산자들의 기호는 덧셈은 +, 뺄셈은 -, 실수 나눗셈은 /, 정수 나눗셈은 //, 곱셈은 *, 나머지는 %,지수는 **이다. 
# 이러한 연산자들을 이용하여 계산을 해보자. 7과 4를 가지고 계산을 해 볼 것이다. 
# 먼저, 덧셈부터 시작해 보자. 덧셈은 7+4이다. 이것을 사용하여 파이썬으로 계산을 해 보니 값이 11이 나온다는 것을 알 수 있다. 실제로 걔산을 헤 보니 파이썬이 계산한 값과 동일한 답이 나와 맞는 계산임을 알 수 있다
# 다음으로는 뺄셈 계산을 해 볼 것이다.뺄셈은 7-4이다. 파이썬을 이용히여 계산을 해 보니 값이 3이 나온다는 것을 알 수 있다. 실제로 계산을 해 보았을 때도 3이 나오는 것을 보아 맞는 계산임을 알 수 있다.
# 그 다음으로 곱셈 계산을 해 볼 것이다. 곱셈의 연산자는 *이다. 이것을 활용하면 7*4라는 식이 나온다. 파이썬을 이용하여 계산해 보니 28이라는 값이 나오는데 실제계산도 같은 값이 나오는 것으로 보면 정답임을
#알 수 있다.
# 그 다음으로 정수 나눗셈을 해 볼 것이다. 정수 나눗셈의 연산자는 //이고, 이러한 정수 나눗셈은 초등학교에서 베웠듯이 나누어서 몫이 나오고 나머지가 나오는 계산법이다. 위의 숫자를 활용하여 계선을 해 보자.
#정수 나눗셈의 식은 7//4 가 된다. 이러한 식을 파이썬으로 계산햐여 보니 1이 나온다. 실제로도 몫이 1이 나오고 나머지는 3이 나오기 때문에 이것은 맞는 계산이라고 할 수 있다.
# 그 다음으로는 실수 나눗셈 연산자를 사용하여 계산해 볼 것이다. 실수 나눗셈은 우리가 가장 잘 알고 계산기로 하면 나오는 나눗셈이 바로 이 실수 나눗셈이라고 할 수 있다. 위의 숫자를 활용해 계산식을 만들었다.
#계산식을 해 보니 7/4가 된다. 이것을 사용하여 파이썬으로 계산을 해 보자. 1.75가 답으로 나온다. 실제로도 계산을 해 보니 동일한 답이 나오므로 맞는 답이라고 할 수 있다. 
# 다음으로, 나머지 연산자를 활용하여 계산을 해 볼 것이다. 나머지 연산자는 %이다. 이 연산자를 활용하고 위의 숫자를 사용해 계산삭을 만들어 보니 계산식이 7%4가 나온다.
#파이썬을 활용하여 계산해보고 실제 계산도 해 보았더니 나머지로 3이 나오는 것을 알 수 있다. 
# 다음으로 지수 연산자를 활용해 계산식을 만들고 계산해 보았다. 이것은 7의 3승을 하면 값이 너무 커지므로 2의 3승으로 대체하였다. 계산식은 2**3이고 값은 8이 나온다. 
#이 외에도 비트 이동 연산자(>>,<<), 비트 AND 연산자(&), 비트 XOR 연산자(^), 비트 OR 연산자(|), 비교 연산자(<=,<,>,>=), 동등 연산자(<> == !=),
# 대립 연산자(= %= /= //= -= += *= **=), 아이덴티티 연산자(is is not), 소속 연산자(in not in), 
#논리 연산자(not or and), 관계 연산자(x==y(x와 y가 같은가?), x!=y(x와 y가 다른가?), x>y(x가 y보다 큰가?), x<y(x가 y보다 작은가?), x>=y(x가 y보다 크거나 같은가?), x<=y(x가 y보다 작거나 같은가?)), 
#논리 연산자(x and y(AND연산,x와 y가 모두 같으면 참, 아니면 거짓), x or y(OR 연산,x나 y중에서 하니만 참이면 참, 모드 거짓이면 거짓), not x(NOT 연산,x가 참이면 거짓, x가 거짓이면 참))   
#이렇게 연산자에 대해 알아보았다. 다음으로는 조건식에 대해 알아볼 것이다.
#파이썬의 조건식은 TRUE인 경우만 고려하는 단일조건식, TRUE일 경우와 FALSE일 경우를 고려하는 조건식, if/elif/else 다중 조건식이 있다. 
#TRUE일 경우만 고려하는 단일 조건식에서는 TRUE일 경우만 실행되는 조건식이다.
#TRUE일 경우와 FALSE일 경우를 고려하는 조건식은 조건식이 TRUE일 경우나 FALSE일 경우만 실행되는 조건식을 말한다.
#if/elif/else 다중 조건식은 조건식이 여러가지 있는 경우를 말한다. 처음 조건식은  if로 쓰고 그 다음부터는 elif, 마지막 조건식, 즉, 아닌 앞의 조건을 모두 충족하지 못하였을 경우에는 else를 사용한다.
