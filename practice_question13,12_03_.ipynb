# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/practice_question13%2C12_03_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.원을 나타내는 클래스 Circle를 정의해보자 Circle클래스에 포함되는 변수와 함수는 다음과 같다. Circle클래스의 객채를 생성하고 테스트해보자
2.TV를 클래스로 정의해보자.TV클래스는 다음과 같은 변수들과 함수들을 가진다.TV클래스의 객채를 생성하고 테스트 해보자
3터틀 그래팩에서 각각의 거북이는 객체이다. 2개의 거북이를 생성하여서 다음과 같이 서로 다른 방향으로 움직이도록 하자.
4.아주 간단한 예제로 상속을 실습해보자. 터틀 그래픽에서 Turtle도 클래스이다.이것을 상속받아서 MyTurtle 클래스를 작성한다. MyTurtle 클래스는 기존의 Turtle 클래스에 하나의 함수만을 추가하는데 바로 다음과 같이 
사각형을 그리는 함수이다. 

1.
class Circle:
  def__init__(self,radius):
    self.radius=radius

  def calcPerimeter(self):
    self.calcPerimeter=2*3.141592*self.radius**2

  def calcArea(self):
    self.area=3.141592*self.radius**2

  def__str__(self):
    return "반지름: "+str(self.radius)+"원의 둘레: "+str(self.perimeter+"원의 면적: "+str(self.area))

r=int(input("반지름: "))
x=Circle(r)
x.calcPermeter()
x.calcArea()

print(x)

2.
class TV:
  def__init__(self,channel,volum,on):
    self.channel=channel
    self.volume=volume
    self.on=on

  def turnOn(self):
    self.on=1
  def turnOff(self):
    self.on=0

  def setChannel(self,channel):
    self.channel=channel

  def setvolume(self,volume):
    self.volume=volume

  def __str__(self):
    if self.on==1:
      msg="TV의 채널: "+str(self.channel)+"TV의 음량: "+str(self.volume)
    else:
      msg="TV가 꺼져있습니다."
    return msg

def remote_Onoff():
  global on
  on_r=str(input("티비를 켤까요?(y/n): "))
  if on_r=="y":
    on=1
  elif on_r="y":
    on=0
  else:
    print("처음부터 다시 입력하시오.")

def remote_Channel():
  global channel
  channel=int(input("채널을 입력해주세요: "))

def remote_Volume():
  global volume
  volume=int(input("볼륨을 입력해주세요.: "))

remote_Onoff()
if on == 1:
  remote_Channel()
  remote_volume()
else:
  channel=0
  volume=0
myTV=TV(channel,volume,on)
print(myTV)    

3.
from turtle import 
import turtle

class Tu:
  def __init__(self,speed,shape):
    self.speed=speed
    self.turtle=Turtle()
    self.turtle.shape(shape)

  def drive(self):
    self.turtle.forward(self,speed)

  def turn(self,num):
    if num ==1:
      self.turtle.right(90)
    elif num ==2 :
      self.turtle.left(90)

lee=Tu(100,"turtle")
kim=Tu(100,"circle")

for i in range(20):
  j=random.randint(1,2)
  k=rnadom.randint(1,2)
  kim.turn(j)
  lee.turn(k)
  lee.drive()
  kim.drive()


4.
import turtle

class MyTurtle(turtle.Turtle):
  def drawSqure(self):
    for i in range(4):
      self.right(90)
      self.forward(100)

my_turtle=MyTurtle()
my_turtle.forward(100)
my_turtle.drawSqure()
