# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/chllange_question_6%2C11_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.정육각형은 어떻게 그리면 되는가? 반드시 반복을 사용해서 그려보자.
2.n각형의 한 변의 크기도 사용지로 부터 받아보자 forward(100)이 아니고 forward(len)가 되도록 하라
3.거북이가 90도로만 방향을 전환할 수 있다면 위의 프로그램은 어떻게 수정되어야 할까? 거북이는 90도,180도,270 도, 360도 중에서 하나를 선택하여 앞으로 전진한다.
4.구구단의 1단부터 9단까지 모두 출력하도록 위의 프로그램을 수정해 보자.
5.무한 루프 위의 코드에서 8번 문장을 삭제하고 실행시켜 보자. 어떤일이 발생하는가? 이것을 무한 루프라고 한다. 거북이가 무척 고생을 한다.
6.시도 횟수를 최대 10번으로 제한하려면 위의 프로그램을 어떻게 변경하여야 하는가?
7.덧셈뿐만 아니라 뺄셈 문제도 출제 할 수 있도록 위의 프로그램을 수정하여라.
8.위의 프로그램은 얼마든지 다른 방식으로 작성이 가능하다 8개의 문자열을 8개의 변수에 저장하고 if문에서는 해당 변수를 출력하는 식으로 코드를 변경해 보자.

1.
import turtle   #turtle 모듈은 불러온다
t=turtle.Turtle() #turtle을 t로 선언
t.sjape("turtle") #turtle 모듈의 아이콘을 거북이 모양으로 선언

for i in range(6): #6번 반복
  t.forward(100) #100픽셀 직진
  t.left(360/6) #(360/6)도 만큼 왼쪽으로 회전
2
import turtle #turtle 모듈을 불러온다
t= turtle.Turtle() #turtle을 t로 선언
t.shape("turrtle") #turtle 모듈의 아이콘을 거북이 모양으로 선언

s=turtle.textinput("","몇각형을 원하시나요?: ") 
n=int(s)
s=turtle.textinput("","한변의 크기를 입력해주세요.: ")
len=int(s)
for i in range(n): #n번 반복한다
  t.forward(len) #len 픽셀 만큼 전진
  t.left(360/n) #(360/n)만큼 왼쪽으로 회전

3.
import turtle #turtle 모듈을 불러온다
t= turtle.Turtle() #turtle을 t로 선언
t.shape("turtle") #turtle 모듈의 아이콘을 거북이 모양으로 선언

for i in range(30): #30번 반복
  length=random.randint(1,100) #(1,100)에서 랜덤으로
  t.forward(100) #100픽셀 만큼 전진
  angle=randim.randint(1,4) #(1,4)에서 랜덤으로 지정
  t.right(90*angle) #(90*angle)만큼 왼쪽으로 회전

i=1 #i 변수와 변수값 선언  
while i <=9: #변수가 9보다 작거나 같을 때 반복
  j=1 #j변수와 변수값 선언
  while j <=9: #변수 j가 9보다 작거나 같을 때 반복
    print("*",j,=",i*j") 
    j=j+1 
  print(" ")
  i=i+1

4.
import turtle #turtle 모듈을 불러온다
t=turtle.Turtle() #turtle을 t로 선언
t.shape("turtle") #turtle 모듈의 아이콘을 거북이 모양으로 한다

i=0 #변수 i와 변수값 선언
while i <5: #변수 i가 5보다 작을 때 반복
  t.forward(50) #50 픽셀 만큼 직진
  t.right(144) #144도 오른쪽으로 회전

5.
import turtle #turtle 모듈을 불러온다
import random #random 모듈을 불러온다
colors=["red", "purple", "blue", "green", "yellow", "orange"] #색상은 리스트에 저장했다가 하나씩 꺼내서 변경하도록 하자
t=turtle.Turtle() #turtle을 t로 한다

t.bgcolor("black") #배경색을 검정으로 한다
t.speed(0) #속도는 0으로 한다
t.width(3) #선의 굵기는 3이다

iength=10 #length 변수를 선언하고 값을 지정한다
while length < 500 : #leagth 변수가 500보다 작을 때 반복
  t.forward(length) #length 만큼 직진
  t.pencolor(colors[length%6]) #선의 색상 지정
  angle=random.randint(1,100) # angle 변수 선언하고 변수값을 (1,100)에서 랜덤하게 지정 
  t.right(angle) #angle만큼 오른쪽으로 회전
  length + = 5  #선의 길이를 5만큼 증가시킨다

6.
import random #random 모듈을 불러온다
tries = 0 #tries 변수 선언하고 변수값 선언
guess = 0 #guess 변수 선언하고 변수값 선언
answer = random.randint(1,100) #answer 변수 선언하고 변수값을 (1,100)사이에서 지정

print("1부터 100 사이의 숫자를 맞추시오.: ")

while guess ! = answer : #guess 변수와 answer변수가 같으면 반복
if tries < 10 : 
  tries=tries+1 
  if guess < answer:
    print("낮음!")
  elif guess > answer :
    print("높음!")
  else:
    print("시도 횟수를 초과하였습니다.")
    break    

if guess == answer:
  print("정딥은 ",answer)

7.
import random #random 모듈을 불러온다

while True: #True의 경우 반복
  q=random.randont(0,1)  #q변수 선언하고 변수값은 (0,1)에서 랜덤 지정
  x=random.randint(1,100) #x변수 선언하고 변수값은 (1,100)에서 랜덤 지정
  y=random.randint(1,100) #y변수 선언하고 변수값은 (1,100)에서 랜덤 지정
  if (q==1) & (x>y) :
    print(x,"-",y,"=",end=" ")
    answer = int(input())
    if answer == x-y:
      print("잘했어요!")
    else:
      print("다음번에는 잘할 수 있죠?")
  else:
    print(x,"+",y,"=",end=" ")
    answer = int(input())
    if answer ==x+y:
      print("잘했어요!")
    else:  
      print("다음번에는 더 잘 할 수 있죠?")

8.
import random #random 모듈을 불러온다
number = random.randint(1,8) #number변수 선언하고 변수값은 (1,8)사이에서 랜덤 지정

list = ["한 점의 의심도 없이 맞습니다.", "할 수 있습니다.", "물론입니다.", "글쎄요, 열심히 해야 할 것입니다.", "안 될것 같습니다","조금 더 노력하세요.", "행운을 빕니다","다음달에 할 수 있을 겁니다."]
#문장을 리스트에 저장
while True: True일 경우 반복
  name =input("이름:(종료하려면 엔터키)")
  if name =="":
    break;
  question = input("무엇에 대하여 알고 싶으신가요?")
  print(name, "님", "\", question,""\"에 대해 질문주셨군요.")
  print(list[number-1])
