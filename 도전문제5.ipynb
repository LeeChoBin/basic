# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/%EB%8F%84%EC%A0%84%EB%AC%B8%EC%A0%9C5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.15세 이상이면 "이 영화를 보실 수 있습니다"메세지에 추가로 "이 영화의 가격은 10000원 입니다"를 출력해보자. 만약 15세 미만이면 "이 영화를 보실 수 없습니다"메세지에 추가로 "다른 영화를 보시겠어요?를 출력해보자"
age=int(input("나이를 입력하시오: ")) #변수 age를 선언하고 정수형으로 받음
if age >=15: #나이가 15세 이상일 때
  print("이 영화를 보실수 있습니다. 이 영화의 가격은 10000원 입니다.")
else: #나이가 15세 이하일 때
  print("이 영화를 보실 수 없습니다. 다른 영화를 보시겠어요?")

2.
(1)사용자가 "l"또는"left"를 입력하면 왼쪽으로 움직이고 "r"또는"right"를 입력하면 오른쪽으로 이동하도록 소스를 약간 변형해보자
import turtle #turtle모듈을 불러온다
t=turtlr.Turtle() #turtle을 t로 선언한다
t.width(3) #거북이가 그리는 선의 두께를 3으로 한다
t.shape("turtle") #turtle모듈의 아이콘은 거북이 모양으로 한다
t.shapesize(3,3) #거북이를 3배 확대

while answer: #무한루프
  command=input("명령을 입력하시오: ")
  if command == "l" or command =="left": #"l"또는"left" 입력
    t.left(90)
    t.forward(100)
  if command =="r" or command=="right": # "r"또는"right" 입력
    t.right(90)
    t.forward(100)

(2)사용자가 "q"또는"quit"를 입력했을 때, 프로그램을 종료하도록 하라.
import turtle #turtle모듈을 불러온다

t=turtle.Turtle() #turtle을 t로 선언
t.width(3) #거북이가 그리는 선의 두께를 3으로 한다
t.shape("turtle") #turtle 모듈의 아이콘을 거북이 모양으로 한다
t.shapesize(3,3) #거북이를 3배 확대한다

flag=True 

while flag: #루프 제어편수인 flag를 둔다
  command=input("명령을 입력하시오: ")
  if command =="l"or command == "left": # "l" 또는"left" 입력
    t.left(90)
    t.forward(100)
  if command == "r" or command == "right": #"r" 또는 "right" 입력
    t.right(90)
    t.forward(100)
  if command == "q" or command == "quit": #"q" 또는 "quit" 입력
     flag = False
        
3.주사위 던지기 게임으로 변환해 보자. random.randrange(6)하면 0에서 5까지의 정수를 랜덤하게 생성할 수 있다.
import turtle #turtle모듈을 불러온다

print("주사위 게임을 시작합니다.")
dice = random.randint(6)+1
print("주사위 눈은"+str(dice)+"입니다.")
print("게임이 종료되었습니다.")

4.종달새가 6시와 9시 사이 또는 14시와 16시 사이에 노래한다고 하면(그리고 날씨는 항상 화창하여야 한다) 위 조건식을 어떻게 변경하여야 하는가?
import random
time= random.randint(1,24)
print("좋은 아침 입니다. 지금 시각은 "+str(time))+"시 입니다.")
sunny = random.choice([True,False])
if sunny: #날씨가 회창함
  print("현재 날씨가 화창합니다")
else: #날씨가 회창하지 않음
  print("현재 날씨가 화창하지 않습니다")

if time >= 6 and  time <9 and True: #6시에서 9시 사이고 날씨 회창
  print("종달새가 노래를 한다")
elif time >= 14 and time <16 and True: #14시 16시 사이고 날씨 회창
  print("종달새가 노래를 한다.") 
else: #그 외의 경우
  print("종달새가 노래를 하지 않는다.")
     
5.아이디 검사가 종료되면 바로 패스워드 검사를 해보자. 즉 다음과 같은 출력을 가지는 프로그램을 작성한다.
id = "ilovepython"
pw = "123456"
s =input("패스워드를 입력하시오: ")
if s == id: 
  p = input("패스워드를 입력하시오.")
  if p == pw: #모두 일치
    print("환영합니다.")
  else: #비밀번호 불일치
    print("비밀번호가 잘못되었습니다.")
else:# 그 외의 경우
  print("아이디를 찾을 수없습니다.")    

6.골대를 더 여러 영역으로 나누어서 게임을 다시 작성해 보자. 즉, 왼쪽 상단, 왼쪽 하단, 중앙, 오른쪽 상단, 오른쪽 하단 중에서 하나를 선택하도록 한다
import random #random 모듈 불러옴

options = ["왼쪽 상단","왼쪽 하단","중앙","오른쪽 상단","오른쪽 하단"]
computor_choice = random.choice(options)
user_choice = input("어디를 수비하시겠어요?(왼쪽 상단,왼쪽 하단,중앙,오른쪽 상단,오른쪽 하단)") #변수 user_choice 선언
if computer_choice == user_choice: #컴퓨터와 유저의 선택 일치
  print("수비에 성공하셨습니다")
else: #컴퓨터와 윳저의 선택 불일치
  print("페널티 킥이 성공하였습니다.")  

7.위의 프로그램에서 "사각형"만 지원하고 있다."삼각형","원"인 경우에 동형을 그리는 코드를 추가해라
import turtle #turtle 모듈울 불러옴
t=turtle.Turtle() #turtle을 t로 선언
t.shape("turtle") #turtle 모듈의 아이콘을 거북이 모양으로 선언

s =turtle,textinput("","도형을 입력하시오: ")
if s == "사각형": #사각형일때
  s = turtle.textinput("","가로: ") #가로의 길이 설정
  w = int(s) #변수 w를 선언하고 정수형으로 받음
  s = turtle.textinput("","세로: ") #세로의 길이 설정
  h = int(s) #변수 h를 선언하고 정수형으로 받음
  t.forward(w)
  t.left(90)
  t.forward(h)
  t.left(90)
  t.forward(w)
  t.left(90)
  t.forward(h)
elif s =="삼각형":#삼갹형일 때
  s = turtle.textinput("","변: ") #삼각형의 변의 길이 설정
  l = int(s) #변수 l을 선언하고 정수형으로 받음
  t.forward(l)
  t.left(120)
  t.forward(l)
  t.left(120)
  t.forward(l)
elif s == "원": #원일 때
  s = turtle.textinput("","반지름: ") #반지름의 길이 설정
  r = int(s) #변수 r를 선언하고 정수형으로 받음
  t.circle(r) 
else: #셋 다 아님
  pass
