# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/practice_question7%2C11_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.눈사람을 그리는 함수를 작성하고 이 함수를 여러 번 호출하여서 랜덤한 위치에 눈사람을 그리는 프로그램을 작성하라. 아래 실행 결과와 최대한 비슷하게 작성해보자. 
2.6각형을 그리는 draw_hexa()함수를 작성하고 이 함수를 호출하여서 다음과 같은 벌집 모양을 화면에 그려보자.
3.함수 f(x)=x**2+1을 계산하는 함수를 작성하고 이 함수를 이용하여 화면에 f(x)를 그려보자.
4.터틀 그래픽에서 거북이를 움직이지 않고 선을 긋는 함수 draw_line()ㅡㅇㄹ 정의하고 이것을 이용하여 다음과 같은 거미줄과 같은 모양을 그려보자. 거북이는 항상 중앙에 위치한다.
5.다음과 같이 이름을 받아서 생일 축하 노래를 출력하는 함수 happyBirthday()를 작성하고 테스트하시오.
6.사용자로부터 2개의 정수를 받아서 수학문제를 만들어서 화면에 출력하는 함수를 작성하고 테스트하시오.
7.파이를 나타내는 PI=3.14를 전역 변수로 하여 원의 면적을 계산하는 함수 circleArea(radius)과 원의 둘레를 계산하는 함수 circleCircumference(radius)를 작성하고 테스트하시오. 
8.덧셈,뺄셈,곱셈,나눗셈을 수행하는 함수를 각각 작성하고 테스트하라.

1.
import turtle
t=turtle.Turtle()
t.shape("turtle")
t.color("black,white")
def draw_snowman(x,y):
  t.up()
  t.goto(x,y)
  t.down()
  t.begin_fill()
  t.circle(20)
  t.end_fill()
  t.goto(x,y-25)
  t.forward(50)
  t.backword(50)
  t.seathing(0)

  t.begin_fill()
  t.circle(30)
  t.end_fill()
  t.goto(x,y-70)
  t.begin_fill()
  t.circle(30)
  t.end_fill()

draw_snowman(0,0)
draw_snowman(100,0)
draw_snowman(200.0)

2.
import turtle
t=turtle.Turtle()
t.shape("turtle")
t.speed(0)

def hexagon():
  for i in range(6):
    turtle.forward(100)
    turtle.left(360/6)
  for j in range(6):
    hexagon()
    turtle.forward(100)
    turtle.right(360/6)  

3.
import turtle
t=turtle.Turtle()
t.shape("turtle")
t.speed(0)

def f(x):
  return x**2+1
t.goto(200,0)
t.goto(0,0)
t.goto(0,200)
t.goto(0,0)

for x in range(150):
  t.goto(x,int(0.01*f(x)))

4.
#거북이를 약간씩 회전시키면서 draw_line()을 호출하면 된다.
import turtle
t= turtle.Turtle()
t.shape("turtle")
t.speed(0)

def draw_line():
  t.forward(100)
  t.backward(100)

for x in range(12):
  t.right(30)
  draw_line()
      
5.
#매개변수를 통해 이름을 받으면 된다.
def happyBirthday(person):
  print("Happy Birthday to you!")
  print("Happy Birthday to you!")
  print("Happy Birthday, dear " + person)
  print("Happy Birthday to you!")

happyBirthday("홍길동")

6.
def sumProblem(x,y):
  sum=x+y
  sentense = "정수" + str(x) + "+" +str(y)+ "의 합은?"
  print(sentence)

def main():
  a=int(input("첫번째 정수: "))
  b=int(inpit("두번째 정수: "))
  sumProblem(a,b)

main()  

7.
#PI 변수를 함수의 외부에서 받으면 전역 변수가 된다. 전역 변수는 함수 안에서 사용할 수 있다.
PI=3.14159265358979

def circleArea(radius):
  return PI*radius*radius

def circleCircumference(radius):
  return PI*radius

def main():
  print("반지름이 5인 원의 면적",circleArea(5))
  print("반지름이 5인 원의 둘레",circleCircumference(5))

main()

8.
def add(a,b):
  print("(%d+%d)"%(a,b),end="")
  return a+b

def subtract(a,b):
  print("(%d-%d)"%(a,b),end="")
  return a-b

def multiply(a,b):
  print("(%d*%d)"%(a,b),end="")
  return a*b

def divide(a,b):
  print("(%d/%d)"%(a,b),end="")
  return a/b

what=add(20,10)
print("=",what)
