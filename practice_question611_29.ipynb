# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/practice_question611_29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.2부터 100 사이의 모든짝수를 출력하는 반복 루프를 작성한다.
2.어떤 사람이 복리 이자율 7%로 1000만원을 저금하였을 경우에 2000만원이 되는데 몇년이 걸리는지 계산하기 위하여 다음과 코드를 작성하였다. 잘못된 점은 없는지 체크해 보자.
3.다음 코드의 출력을 예상해 보자. 각 단계에서 변수의 값을 예상해보시오
4.사용자에게 곱셈 퀴즈를 내고 답을 사용자로부터 받는 프로그램에서 사용자가 올바른 답을 입력할 때까지 반복하도록 수정하여 보자.
5.사용자가 입력한 정수의 합을 계산하는 프로그램을 닥성하자. 사용자가 0을 입력하기 전까지 계속하여 읽도록 한다.
6.난수 생성 함수를 사용하여서 2개의 주사위를 던졌을 때 나오는 수를 다음과 같이 출력하여보자.
7.터틀 그래픽과 반복을 사용하여 눈 모양을 그려보자
8.우리는 이번장에서 터틀 그래픽으로 별을 그려보았다. 이 코드를 응용하여 다음과 같이 10개의 별을 그리는 프로그램을 작성하라. 별들은 시작 각도가 약간씩 다르다.
9.반복과 난수를 함께 사용하면 화면에 랜덤한 원을 그릴 수 있다. 화면에 10개의 랜덤한 원을 그리는 프로그램을 작성하라. 원의 중심과 반지름이 모두 난수이어야 한다.
10.다음과 같이 거북이를 왕복 달리기시키는 프로그램을 작성해보자.
11.다음의 터틀그래픽 프로그램을 분석해보자. 학습하지 않은 함수가 있다면 인터넷에서 조사하여 보자 
12.터틀 그래픽과 반복을 사용하여 싸인 그래프를 그려보자. 거북이를 싸인값에 따라서 움직이면 된다.

1.
for i in range(1,101):
  if (i%2==0): #i%2한 결과가 0이면 i는 짝수 
    print(i,end="")

2.
years=0
balance=1000
while balance<=2000: 
  year=year+1
  interrest=balance*0.07
  balance=balance+interest
print(year,"년이 걸립니다.")

3.
n=123
sum=0
while n> 0:
  digit=n%10
  sum=sum+digit
  n=n//10
print(sum)

4.
import random 

x=random.randint(1,10)
y=random.randint(1,10)

correct=x*y
while True:
  user=int(input("%s*%s는"%(x,y)))
  if(user==correct):
    print("맞았습니다.")
    break 

5.
#무한 루프를 작성하고 사용자가 입력한 값이 0이면 break 문장을 실행해 반복 루프를 빠져나간다. 무한 루프는 while True:로 만든다.
usm=0
while True:
  user = int(input("정수를 입력하시오.: "))
  sum +=user
  if(user==0):
    break

print("합은 %s 입니다" %sum)

6.
#1부터 6 사이의 난수를 발생하려면 r=random.randint(1,6) 문장을 사용함. 프로그램의 첫부분에 import random 문장도 추가해야 함
import random

for i in range(3):
  r1=random.randint(1,6)
  r2=random.randint(1,6)
  print("첫번째 주사위= %s 두번째 주사위=%s" )

7.
import random
t=turtle.Turtle()
t.shape("turtle")

for i in range(6):
  t.left(60)
  t.forward(100)
  t.forward(-30)
  t.left(60)
  t.forward(30)
  t.forward(-30)
  t.right(120)
  t.forward(30)
  t.forward(-30)
  t.left(60)
  t.forward(-70)

8.
#별을 그리는 코드를 반복한다. 하나의 별을 그리는 반복이 끝나면 left(10)을 실행한다
import random
t=turtle.Turtle()
t.shape("turtle")
t.color("red")

for i in range(10):
  for j in range(5):
    t.left(144)
    t.forward(100)
  t.left(10)

9.
#원의 중심, 원의 반지름은 모두 난수로 설정한다. 
import turtle 
import random 

t=turtle.Turtle()
t.shape("turtle")

for i in range(10):
  x=random.randint(1,100)
  y=random.randint(1,100)
  r=random.randint(1,100)

  t.up()
  t.goto(x,y)
  t.down()
  t.circle(r)


10.
import turtle
t=turtle.Turtle()
t.shape("turtle")

for i in range(5):
  t.forward(100)
  t.left(90)
  t.forward(20)
  t.right(90)
  t.forward(100)
  t.left(90)
  t.forward(20)
  t.left(90)

11.
#color(c1,c2)함수는 도형의 선색상과 채우기 색상을 c1과 c2로 설정한다. begin_fill()를 호출하면 속이 채워진 도형이 그려진다. pos()함수는ㄴ 거북이의 좌표를 반환한다. abs()는 절대값을 계산함
if abs(t.pos())<1:
  break
  #현재 거북이 위치 좌표의 절대값이 1보다 작을 때, 반복 루프를 빠져나와라. 

12.#싸인값은 sin()함수로 계산이 가능하다. 프로그램의 첫 부분에 import math를 추가한다. 각도를 라디안으로 변환하여야 한다. radian=3.14*degree/180 수식을 사용한다.
import turtle
t=turtle.Turtle()
t.shape("turtle")

for x in range(360):
  t.goto(x,200*math.sin(3.14*x/180))
