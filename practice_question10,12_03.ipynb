# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeChoBin/basic/blob/main/practice_question10%2C12_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1.다음과 같이 하나의 레이블과 2개의 버튼을 가지는 프로그램을 작성해보자
2.숫자를 입력하고 "더하기" 버튼을 누르면 합계에 더해지고 "빼기" 버튼을 누르면 합계에서 빼지는 계산기를 작성하여 본다
3.우리가 앞에서 텍스트 버젼으로 제작하였던 숫자 맞추기 게임을 그래픽 사용자 인터페이스 버젼으로 작성해보자 
4.인치를 센티미터로 변환하는 다음과 같은 프로그램을 작성해보자
5.데이터를 입력 받을 때 사용할 수 있는 다음과 같은 애플리케이션을 작성해보자
6.가위,바위,보 게임을 GUI 버젼으로 작성해보자. 사용자의 선택을 왼쪽에 이미지로 표시한다. 컴퓨터의 선택은 오른쪽에 이미지로 표시한다. 사용자는 버튼을 눌러서 가위,바위,보 중에서 하나를 선택할 수 있다.
 사용자의 선택이 끝나면 결과를 화면에 텍스트로 표시한다

1.
from tkinter import
window=TK()

label=Label(window,text="간단한 GUI 프로그램")
welcome=Button(wondow,text="환영합니다.")
exit_=Button(window,text="환영합니다.")
label.pack()
welcome.pack()
exit_.pack()

window.mainloop()

2.
from tkinter import

total=0

def add():
  global total
  total=total+int(entry.get())
  SumNum.config(text=str(total))

def minus():
  global total
  total=total-int(entry.get())
  SumNum.config(text=str(total)) 

window=TK()

total=0

NowSum=Label(window,text="현재 합계")
SumNum=Label(window,text=total)
NowSum.grid(row=0,column=0)
SumNum.grid(row=0,column=1)

entry=Entry(window,text="현재 합계")
entry.grid(row=1,column=0,columnspan=3)

addbutt=Button(window,text="더하기(+)",command=add)
minusbutt= Button(window,text="빼기(-)",command=minus)
resebutt=Button(window,text="reset",command=reset)

addbutt.grid(row=2,column=0)
minusbutt.grid(row=2,column=1)
resetbutt.grid(row=2,column=2)

window.mainloof()

3.
from tkinter import
import random

msg="숫자를 입력해주세요(1-100)"
answer=random.randont(1,100)
def insert_num():
  num=int(entry.get())
  if answer==num:
    msg="정답이예요"
    Text.config(text=msg)
  elif answer<num:
    msg="높아요"
    Text.config(text=msg)
  elif answer>num:
    msg="낮아요"
    Text.config(text=msg)

def reset():
  global answer
  answer=random.randont(1,100)
  msg="숫자를 입력해주세요(1-100)"
  Text.config(text=msg)

window=TK()

Text=Label(window,width=30,text=msg)
Text.grid(row=1,column=0,columnspan=2)

entry=Entry(window)
entry.grid(row=1,column=0,columnspan=2)

insert_butt=Button(wimdow,text="숫자입력",command=insert_num)
reset_butt=Button(window,text="재시작", command=reset)
insert_butt.grid(row=2,column=0)
reset_butt.grid(row=2,column=1)

window.mainloof()

4.
from tkinter import
def inch_to_cm():
  inch_val=int(entry.get())
  cm_val=str(inch_val*2.54)
  labF.config(text=cm+val+"센티미터")

window=TK()

lab1=Label(window,text="인치를 센테미터로 변환하는 프로그램")
lab1.grid(row=0, column=0,columnspan=2)

lab2=Label(window,text="인치를 입력하시오.")
entry=Entry(window)
lab2.grid(row=1,column=0)
entry.grid(row=1,clumn=1)

lab3=Label(window,text="변환 결과")
labF=Label(window,text="")
lag3.grid(row=2,column=0)
labF.grld(row=2,column=1)

lab4=Label(window)
But1=Label(window,text="변환",command=inch_to_cm)
lab4.grid(row=3,column=0)
But1.grid(row=3,column=1)

window.mainloof()

5.
from tkinter import
window=TK()

lab_name=Label(window,text="이름")
entry_name=Entry(window)
lab_name.grid(row=0,column=0,columnspan=2)
entry_name.grid(row=0,column=2)

lab_job=Label(window,text="직업")
entry_job=Entry(window)
lab_job.grid(row=1,column=0,columnspan=2)
entry_job.grid(row=1,column=2)

lab_Nation=Label(window,text="국적")
entry_Nation=Label(window)
lab_Nation.grid(row=2,column=0,columnspan=2)
entry_Nation.grid(row=2,column=2)

show_butt=Button(window,text="Show")
Quit_butt+Button(window,text="Quit")
blank_lab=Label(window)
show_butt.grid(row=3,colum=0)
Quit_butt.grid(row=3,column=1)
blank_butt.grid(row=3,column=2)

window.mainloof()

6.
from tkinter import
import random

RPS=["가위","바위","보"]
com=random.choice(RPS)

def rock():
  label_user.config(text="바위")
  label_comp.config(text=com)
  if com=="가위":
    label_result.config(text="당신의 승리")
    elif com=="바위":
      label_result.config(text="비겼습니다")
    elif com=="보":
      label_result.config(text="당신의 패배")

def scissor():
  label_user.config(text="가위")
  label_comp.config(text=com)
  if com=="보":
    label_result.config(text="당신의 승리")
    elif com=="가위":
      label_result.config(text="비겼습니다")
    elif com=="바위":
      label_result.config(text="당신의 패배")
 
def paper():
  label_user.config(text="보")
  label_comp.config(text=com)
  if com=="바위":
    label_result.config(text="당신의 승리")
    elif com=="보":
      label_result.config(text="비겼습니다")
    elif com=="가위":
      label_result.config(text="당신의 패배")

def reset():
  global com
  com=random.randint.choice(RPS)
  label_result.config(text="가위,바위,보 중 하나를 골라주세요.")
  label_user.config(text="유저")
  label_comp.config(text="컴퓨터")

window=TK()

result="가위 바위 보 중 하나를 골라주세요."

label_user=Label(window,text="유저")
label_vs=Label(window,text="vs")
label_comp=Label(window,text="컴퓨터")
label_user.grid(row=0.column=0)
label_vs.grid(row=0,column=1)
label_comp.grid(row=0,column=2)

label_result=Label(window,text=result)
butt_reset=Button(window,text="reset",command=reset)
label_result.grid(row=1,column=0,columnspan=3)
butt_reset.grid(row=1,column=3)

butt_sci=Button(window,text="가위",width=10,command=scissor)
butt_rock=Button(window,text="바위",width=10,command=rock)
butt_paper=Button(window,text="보",width=10,command=paper)
butt_sci.grid(row=2,column=0)
butt_rock.grid(row=2,column=1)
butt_paper.grid(row=2,column=2)

window.mainloof()
